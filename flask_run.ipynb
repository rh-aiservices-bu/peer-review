# %% [markdown]
# ## Run Flask
# Run your flask app (`wsgi.py`) from here and test it from a separate notebook.

# %%
import sys
# !{sys.executable} -m pip install -r requirements.txt
# Out:
# Collecting Flask
#   Downloading Flask-2.0.3-py3-none-any.whl (95 kB)
#      |████████████████████████████████| 95 kB 30.1 MB/s
# Collecting gunicorn
#   Downloading gunicorn-20.1.0-py3-none-any.whl (79 kB)
#      |████████████████████████████████| 79 kB 128.3 MB/s
# Collecting Werkzeug>=2.0
#   Downloading Werkzeug-2.0.3-py3-none-any.whl (289 kB)
#      |████████████████████████████████| 289 kB 135.6 MB/s
# Collecting itsdangerous>=2.0
#   Downloading itsdangerous-2.1.0-py3-none-any.whl (15 kB)
# Requirement already satisfied: click>=7.1.2 in /opt/app-root/lib/python3.8/site-packages (from Flask->-r requirements.txt (line 1)) (8.0.3)
# Requirement already satisfied: Jinja2>=3.0 in /opt/app-root/lib/python3.8/site-packages (from Flask->-r requirements.txt (line 1)) (3.0.3)
# Requirement already satisfied: setuptools>=3.0 in /opt/app-root/lib/python3.8/site-packages (from gunicorn->-r requirements.txt (line 2)) (60.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/app-root/lib/python3.8/site-packages (from Jinja2>=3.0->Flask->-r requirements.txt (line 1)) (2.0.1)
# Installing collected packages: Werkzeug, itsdangerous, gunicorn, Flask
# Successfully installed Flask-2.0.3 Werkzeug-2.0.3 gunicorn-20.1.0 itsdangerous-2.1.0
# WARNING: You are using pip version 21.3.1; however, version 22.0.3 is available.
# You should consider upgrading via the '/opt/app-root/bin/python3.8 -m pip install --upgrade pip' command.

# %%
# !FLASK_ENV=development FLASK_APP=wsgi.py flask run
# Out:
#  * Serving Flask app 'wsgi.py' (lazy loading)
#  * Environment: development
#  * Debug mode: on
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
#  * Restarting with watchdog (inotify)
#  * Debugger is active!
#  * Debugger PIN: 690-822-609
# 127.0.0.1 - - [23/Feb/2022 19:32:23] "GET /status HTTP/1.1" 200 -
# /opt/app-root/lib64/python3.8/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator SimpleImputer from version 0.24.2 when using version 0.24.1. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# /opt/app-root/lib64/python3.8/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator StandardScaler from version 0.24.2 when using version 0.24.1. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# /opt/app-root/lib64/python3.8/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator Pipeline from version 0.24.2 when using version 0.24.1. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# 127.0.0.1 - - [23/Feb/2022 19:32:25] "POST /predictions HTTP/1.1" 500 -
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.8/site-packages/sklearn/impute/_base.py", line 252, in _validate_input
#     X = self._validate_data(X, reset=in_fit,
#   File "/opt/app-root/lib/python3.8/site-packages/sklearn/base.py", line 421, in _validate_data
#     X = check_array(X, **check_params)
#   File "/opt/app-root/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/opt/app-root/lib/python3.8/site-packages/sklearn/utils/validation.py", line 616, in check_array
#     array = np.asarray(array, order=order, dtype=dtype)
#   File "/opt/app-root/lib/python3.8/site-packages/numpy/core/_asarray.py", line 83, in asarray
#     return array(a, dtype, copy=False, order=order)
#   File "/opt/app-root/lib/python3.8/site-packages/pandas/core/generic.py", line 1899, in __array__
#     return np.asarray(self._values, dtype=dtype)
#   File "/opt/app-root/lib/python3.8/site-packages/numpy/core/_asarray.py", line 83, in asarray
#     return array(a, dtype, copy=False, order=order)
# ValueError: could not convert string to float: 'hello world'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 2091, in __call__
#     return self.wsgi_app(environ, start_response)
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 2076, in wsgi_app
#     response = self.handle_exception(e)
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 2073, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 1518, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 1516, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 1502, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#   File "/opt/app-root/src/experiment-replication/wsgi.py", line 18, in create_prediction
#     return jsonify(predict(body))
#   File "/opt/app-root/src/experiment-replication/prediction.py", line 36, in predict
#     prediction = transformAndPredict(raw, pipeline, model, dropNonBioMarkers = False )
#   File "/opt/app-root/src/experiment-replication/prediction.py", line 20, in transformAndPredict
#     transformed = pipeline.transform(dropped)
#   File "/opt/app-root/lib/python3.8/site-packages/sklearn/pipeline.py", line 560, in _transform
#     Xt = transform.transform(Xt)
#   File "/opt/app-root/lib/python3.8/site-packages/sklearn/impute/_base.py", line 432, in transform
#     X = self._validate_input(X, in_fit=False)
#   File "/opt/app-root/lib/python3.8/site-packages/sklearn/impute/_base.py", line 260, in _validate_input
#     raise new_ve from None
# ValueError: Cannot use median strategy with non-numeric data:
# could not convert string to float: 'hello world'
# /opt/app-root/lib64/python3.8/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator SimpleImputer from version 0.24.2 when using version 0.24.1. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# /opt/app-root/lib64/python3.8/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator StandardScaler from version 0.24.2 when using version 0.24.1. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# /opt/app-root/lib64/python3.8/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator Pipeline from version 0.24.2 when using version 0.24.1. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# 127.0.0.1 - - [23/Feb/2022 19:36:56] "POST /predictions HTTP/1.1" 500 -
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.8/site-packages/sklearn/impute/_base.py", line 252, in _validate_input
#     X = self._validate_data(X, reset=in_fit,
#   File "/opt/app-root/lib/python3.8/site-packages/sklearn/base.py", line 421, in _validate_data
#     X = check_array(X, **check_params)
#   File "/opt/app-root/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/opt/app-root/lib/python3.8/site-packages/sklearn/utils/validation.py", line 616, in check_array
#     array = np.asarray(array, order=order, dtype=dtype)
#   File "/opt/app-root/lib/python3.8/site-packages/numpy/core/_asarray.py", line 83, in asarray
#     return array(a, dtype, copy=False, order=order)
#   File "/opt/app-root/lib/python3.8/site-packages/pandas/core/generic.py", line 1899, in __array__
#     return np.asarray(self._values, dtype=dtype)
#   File "/opt/app-root/lib/python3.8/site-packages/numpy/core/_asarray.py", line 83, in asarray
#     return array(a, dtype, copy=False, order=order)
# ValueError: could not convert string to float: 'None'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 2091, in __call__
#     return self.wsgi_app(environ, start_response)
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 2076, in wsgi_app
#     response = self.handle_exception(e)
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 2073, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 1518, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 1516, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 1502, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#   File "/opt/app-root/src/experiment-replication/wsgi.py", line 18, in create_prediction
#     return jsonify(predict(body))
#   File "/opt/app-root/src/experiment-replication/prediction.py", line 36, in predict
#     prediction = transformAndPredict(raw, pipeline, model, dropNonBioMarkers = False )
#   File "/opt/app-root/src/experiment-replication/prediction.py", line 20, in transformAndPredict
#     transformed = pipeline.transform(dropped)
#   File "/opt/app-root/lib/python3.8/site-packages/sklearn/pipeline.py", line 560, in _transform
#     Xt = transform.transform(Xt)
#   File "/opt/app-root/lib/python3.8/site-packages/sklearn/impute/_base.py", line 432, in transform
#     X = self._validate_input(X, in_fit=False)
#   File "/opt/app-root/lib/python3.8/site-packages/sklearn/impute/_base.py", line 260, in _validate_input
#     raise new_ve from None
# ValueError: Cannot use median strategy with non-numeric data:
# could not convert string to float: 'None'
# 127.0.0.1 - - [23/Feb/2022 19:38:49] "POST /predictions HTTP/1.1" 500 -
# Traceback (most recent call last):
#   File "/usr/lib64/python3.8/json/decoder.py", line 353, in raw_decode
#     obj, end = self.scan_once(s, idx)
# StopIteration: 29
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 2091, in __call__
#     return self.wsgi_app(environ, start_response)
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 2076, in wsgi_app
#     response = self.handle_exception(e)
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 2073, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 1518, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 1516, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 1502, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#   File "/opt/app-root/src/experiment-replication/wsgi.py", line 17, in create_prediction
#     body = json.loads(data)
#   File "/usr/lib64/python3.8/json/__init__.py", line 357, in loads
#     return _default_decoder.decode(s)
#   File "/usr/lib64/python3.8/json/decoder.py", line 337, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/usr/lib64/python3.8/json/decoder.py", line 355, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 30 (char 29)
# /opt/app-root/lib64/python3.8/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator SimpleImputer from version 0.24.2 when using version 0.24.1. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# /opt/app-root/lib64/python3.8/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator StandardScaler from version 0.24.2 when using version 0.24.1. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# /opt/app-root/lib64/python3.8/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator Pipeline from version 0.24.2 when using version 0.24.1. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# 127.0.0.1 - - [23/Feb/2022 19:41:20] "POST /predictions HTTP/1.1" 500 -
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.8/site-packages/sklearn/impute/_base.py", line 252, in _validate_input
#     X = self._validate_data(X, reset=in_fit,
#   File "/opt/app-root/lib/python3.8/site-packages/sklearn/base.py", line 421, in _validate_data
#     X = check_array(X, **check_params)
#   File "/opt/app-root/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/opt/app-root/lib/python3.8/site-packages/sklearn/utils/validation.py", line 616, in check_array
#     array = np.asarray(array, order=order, dtype=dtype)
#   File "/opt/app-root/lib/python3.8/site-packages/numpy/core/_asarray.py", line 83, in asarray
#     return array(a, dtype, copy=False, order=order)
#   File "/opt/app-root/lib/python3.8/site-packages/pandas/core/generic.py", line 1899, in __array__
#     return np.asarray(self._values, dtype=dtype)
#   File "/opt/app-root/lib/python3.8/site-packages/numpy/core/_asarray.py", line 83, in asarray
#     return array(a, dtype, copy=False, order=order)
# ValueError: could not convert string to float: 'hello world'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 2091, in __call__
#     return self.wsgi_app(environ, start_response)
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 2076, in wsgi_app
#     response = self.handle_exception(e)
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 2073, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 1518, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 1516, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 1502, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#   File "/opt/app-root/src/experiment-replication/wsgi.py", line 18, in create_prediction
#     return jsonify(predict(body))
#   File "/opt/app-root/src/experiment-replication/prediction.py", line 36, in predict
#     prediction = transformAndPredict(raw, pipeline, model, dropNonBioMarkers = False )
#   File "/opt/app-root/src/experiment-replication/prediction.py", line 20, in transformAndPredict
#     transformed = pipeline.transform(dropped)
#   File "/opt/app-root/lib/python3.8/site-packages/sklearn/pipeline.py", line 560, in _transform
#     Xt = transform.transform(Xt)
#   File "/opt/app-root/lib/python3.8/site-packages/sklearn/impute/_base.py", line 432, in transform
#     X = self._validate_input(X, in_fit=False)
#   File "/opt/app-root/lib/python3.8/site-packages/sklearn/impute/_base.py", line 260, in _validate_input
#     raise new_ve from None
# ValueError: Cannot use median strategy with non-numeric data:
# could not convert string to float: 'hello world'
# /opt/app-root/lib64/python3.8/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator SimpleImputer from version 0.24.2 when using version 0.24.1. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# /opt/app-root/lib64/python3.8/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator StandardScaler from version 0.24.2 when using version 0.24.1. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# /opt/app-root/lib64/python3.8/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator Pipeline from version 0.24.2 when using version 0.24.1. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# 127.0.0.1 - - [23/Feb/2022 19:41:52] "POST /predictions HTTP/1.1" 500 -
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 2091, in __call__
#     return self.wsgi_app(environ, start_response)
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 2076, in wsgi_app
#     response = self.handle_exception(e)
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 2073, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 1518, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 1516, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 1502, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#   File "/opt/app-root/src/experiment-replication/wsgi.py", line 18, in create_prediction
#     return jsonify(predict(body))
#   File "/opt/app-root/src/experiment-replication/prediction.py", line 36, in predict
#     prediction = transformAndPredict(raw, pipeline, model, dropNonBioMarkers = False )
#   File "/opt/app-root/src/experiment-replication/prediction.py", line 20, in transformAndPredict
#     transformed = pipeline.transform(dropped)
#   File "/opt/app-root/lib/python3.8/site-packages/sklearn/pipeline.py", line 560, in _transform
#     Xt = transform.transform(Xt)
#   File "/opt/app-root/lib/python3.8/site-packages/sklearn/impute/_base.py", line 432, in transform
#     X = self._validate_input(X, in_fit=False)
#   File "/opt/app-root/lib/python3.8/site-packages/sklearn/impute/_base.py", line 262, in _validate_input
#     raise ve
#   File "/opt/app-root/lib/python3.8/site-packages/sklearn/impute/_base.py", line 252, in _validate_input
#     X = self._validate_data(X, reset=in_fit,
#   File "/opt/app-root/lib/python3.8/site-packages/sklearn/base.py", line 437, in _validate_data
#     self._check_n_features(X, reset=reset)
#   File "/opt/app-root/lib/python3.8/site-packages/sklearn/base.py", line 365, in _check_n_features
#     raise ValueError(
# ValueError: X has 1 features, but SimpleImputer is expecting 32 features as input.
# 127.0.0.1 - - [23/Feb/2022 19:44:04] "POST /predictions HTTP/1.1" 500 -
# Traceback (most recent call last):
#   File "/usr/lib64/python3.8/json/decoder.py", line 353, in raw_decode
#     obj, end = self.scan_once(s, idx)
# StopIteration: 29
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 2091, in __call__
#     return self.wsgi_app(environ, start_response)
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 2076, in wsgi_app
#     response = self.handle_exception(e)
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 2073, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 1518, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 1516, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 1502, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#   File "/opt/app-root/src/experiment-replication/wsgi.py", line 17, in create_prediction
#     body = json.loads(data)
#   File "/usr/lib64/python3.8/json/__init__.py", line 357, in loads
#     return _default_decoder.decode(s)
#   File "/usr/lib64/python3.8/json/decoder.py", line 337, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/usr/lib64/python3.8/json/decoder.py", line 355, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 30 (char 29)
# 127.0.0.1 - - [23/Feb/2022 19:44:37] "POST /predictions HTTP/1.1" 500 -
# Traceback (most recent call last):
#   File "/usr/lib64/python3.8/json/decoder.py", line 353, in raw_decode
#     obj, end = self.scan_once(s, idx)
# StopIteration: 29
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 2091, in __call__
#     return self.wsgi_app(environ, start_response)
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 2076, in wsgi_app
#     response = self.handle_exception(e)
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 2073, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 1518, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 1516, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 1502, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#   File "/opt/app-root/src/experiment-replication/wsgi.py", line 17, in create_prediction
#     body = json.loads(data)
#   File "/usr/lib64/python3.8/json/__init__.py", line 357, in loads
#     return _default_decoder.decode(s)
#   File "/usr/lib64/python3.8/json/decoder.py", line 337, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/usr/lib64/python3.8/json/decoder.py", line 355, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 30 (char 29)
# /opt/app-root/lib64/python3.8/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator SimpleImputer from version 0.24.2 when using version 0.24.1. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# /opt/app-root/lib64/python3.8/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator StandardScaler from version 0.24.2 when using version 0.24.1. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# /opt/app-root/lib64/python3.8/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator Pipeline from version 0.24.2 when using version 0.24.1. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# 127.0.0.1 - - [23/Feb/2022 20:01:54] "POST /predictions HTTP/1.1" 500 -
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 2091, in __call__
#     return self.wsgi_app(environ, start_response)
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 2076, in wsgi_app
#     response = self.handle_exception(e)
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 2073, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 1518, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 1516, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 1502, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#   File "/opt/app-root/src/experiment-replication/wsgi.py", line 18, in create_prediction
#     return jsonify(predict(body))
#   File "/opt/app-root/src/experiment-replication/prediction.py", line 36, in predict
#     prediction = transformAndPredict(raw, pipeline, model, dropNonBioMarkers = False )
#   File "/opt/app-root/src/experiment-replication/prediction.py", line 20, in transformAndPredict
#     transformed = pipeline.transform(dropped)
#   File "/opt/app-root/lib/python3.8/site-packages/sklearn/pipeline.py", line 560, in _transform
#     Xt = transform.transform(Xt)
#   File "/opt/app-root/lib/python3.8/site-packages/sklearn/impute/_base.py", line 432, in transform
#     X = self._validate_input(X, in_fit=False)
#   File "/opt/app-root/lib/python3.8/site-packages/sklearn/impute/_base.py", line 262, in _validate_input
#     raise ve
#   File "/opt/app-root/lib/python3.8/site-packages/sklearn/impute/_base.py", line 252, in _validate_input
#     X = self._validate_data(X, reset=in_fit,
#   File "/opt/app-root/lib/python3.8/site-packages/sklearn/base.py", line 421, in _validate_data
#     X = check_array(X, **check_params)
#   File "/opt/app-root/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/opt/app-root/lib/python3.8/site-packages/sklearn/utils/validation.py", line 540, in check_array
#     dtype_orig = np.result_type(*dtypes_orig)
#   File "<__array_function__ internals>", line 5, in result_type
#
# ValueError: at least one array or dtype is required
# 127.0.0.1 - - [23/Feb/2022 20:02:33] "POST /predictions HTTP/1.1" 500 -
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 2091, in __call__
#     return self.wsgi_app(environ, start_response)
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 2076, in wsgi_app
#     response = self.handle_exception(e)
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 2073, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 1518, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 1516, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 1502, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#   File "/opt/app-root/src/experiment-replication/wsgi.py", line 17, in create_prediction
#     body = json.loads(data)
#   File "/usr/lib64/python3.8/json/__init__.py", line 357, in loads
#     return _default_decoder.decode(s)
#   File "/usr/lib64/python3.8/json/decoder.py", line 337, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/usr/lib64/python3.8/json/decoder.py", line 353, in raw_decode
#     obj, end = self.scan_once(s, idx)
# json.decoder.JSONDecodeError: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
